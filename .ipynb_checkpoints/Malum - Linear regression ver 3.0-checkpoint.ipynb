# %% [markdown]
# ##### Preparing the data

# %%
import pandas as pd

#show all the columns and lines in the output
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', 500)

# Putting AmesHousing.txt data into a dataframe - https://github.com/marcelpinheiro/malum/blob/master/AmesHousing.txt
data = pd.read_csv('AmesHousing.txt', encoding='UTF-8', delimiter='\t')
#Removing meaningless to prediction
data = data.drop(['PID','Order'], axis=1)

data
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0              20        RL         141.0     31770   Pave   NaN       IR1
# 1              20        RH          80.0     11622   Pave   NaN       Reg
# 2              20        RL          81.0     14267   Pave   NaN       IR1
# 3              20        RL          93.0     11160   Pave   NaN       Reg
# 4              60        RL          74.0     13830   Pave   NaN       IR1
# ...           ...       ...           ...       ...    ...   ...       ...
# 2925           80        RL          37.0      7937   Pave   NaN       IR1
# 2926           20        RL           NaN      8885   Pave   NaN       IR1
# 2927           85        RL          62.0     10441   Pave   NaN       Reg
# 2928           20        RL          77.0     10010   Pave   NaN       Reg
# 2929           60        RL          74.0      9627   Pave   NaN       Reg
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 0             Lvl    AllPub     Corner  ...         0     NaN    NaN
# 1             Lvl    AllPub     Inside  ...         0     NaN  MnPrv
# 2             Lvl    AllPub     Corner  ...         0     NaN    NaN
# 3             Lvl    AllPub     Corner  ...         0     NaN    NaN
# 4             Lvl    AllPub     Inside  ...         0     NaN  MnPrv
# ...           ...       ...        ...  ...       ...     ...    ...
# 2925          Lvl    AllPub    CulDSac  ...         0     NaN  GdPrv
# 2926          Low    AllPub     Inside  ...         0     NaN  MnPrv
# 2927          Lvl    AllPub     Inside  ...         0     NaN  MnPrv
# 2928          Lvl    AllPub     Inside  ...         0     NaN    NaN
# 2929          Lvl    AllPub     Inside  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 0             NaN        0       5     2010        WD           Normal
# 1             NaN        0       6     2010        WD           Normal
# 2            Gar2    12500       6     2010        WD           Normal
# 3             NaN        0       4     2010        WD           Normal
# 4             NaN        0       3     2010        WD           Normal
# ...           ...      ...     ...      ...        ...             ...
# 2925          NaN        0       3     2006        WD           Normal
# 2926          NaN        0       6     2006        WD           Normal
# 2927         Shed      700       7     2006        WD           Normal
# 2928          NaN        0       4     2006        WD           Normal
# 2929          NaN        0      11     2006        WD           Normal
#
#       SalePrice
# 0        215000
# 1        105000
# 2        172000
# 3        244000
# 4        189900
# ...         ...
# 2925     142500
# 2926     131000
# 2927     132000
# 2928     170000
# 2929     188000
#
# [2930 rows x 80 columns]

# %%
#Let´s find out how many null values we have in the dataset
print(data.isnull().sum().sort_values(ascending=False))

# %%
# Categorical boolean mask
categorical_feature_mask = data.dtypes==object
# filter categorical columns using mask and turn it into a list
categorical_cols = data.columns[categorical_feature_mask].tolist()


#Replace string columns do N/A
data[categorical_cols] = data[categorical_cols].fillna('N/A')
# Replace numeric columns to 0
data = data.fillna(0)
data

# %%
#We need to convert our categorical columns to numbers

from sklearn.preprocessing import LabelEncoder
# instantiate labelencoder object
le = LabelEncoder()

# apply le on categorical feature columns
data[categorical_cols] = data[categorical_cols].apply(lambda col: le.fit_transform(col))
data[categorical_cols].head(10)

# %% [markdown]
# ### **Features**

# %% [markdown]
# #### Feature selection

# %% [markdown]
# ##### Correlation

# %%
# Correlation: We want to know how much correlated our target column 'SalePrice' is with the features
data_corr = data.corrwith(data['SalePrice']).sort_values(ascending=False)
print(data_corr)
data_corr = data_corr[data_corr > 0.3]
data_corr

# %%
#We will use only the columns with the correlation > 0.3
data = data[data_corr.index]
data

# %% [markdown]
# #### Collinearity

# %% [markdown]
# Collinearity is when 2 feature columns are highly correlated and stand the risk of duplicating information. If we have 2 features that convey the same information using 2 different measures or metrics, we don't need to keep both.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(data.corr(), cmap = sns.cm.rocket_r)

# %%
# Gr Liv Area and TotRms AbvGrd has high correlation; 
# Garage Area and Garage Cars too. 
# Let´s choose only one of each
data = data.drop(['Garage Area','TotRms AbvGrd'], axis=1)

# %% [markdown]
# ##### *Variance*

# %%
#LowVariance
from sklearn.preprocessing import MinMaxScaler

SalePrice = data['SalePrice']
data = data.drop('SalePrice',axis=1)

scaler = MinMaxScaler()
dataScaler = scaler.fit(data)
dataScaler = scaler.transform(data)

dataScaler_df = pd.DataFrame(dataScaler, columns= data.columns)

print(dataScaler_df.var().sort_values(ascending = False))


data = data.loc[:,dataScaler_df.var() > 0.010]
data['SalePrice'] = SalePrice
data

# %%
#Agora que selecionamos nossas features, vamos converter novamente nossas categorical features para seus respectivos nomes
#e em seguida vamos usar o get_dummies do pandas para criarmos colunas com cada opção das categorical features,
#no caso apenas a Foundation

#Now we select our features, let's convert our categorical features back to their names
#and then we'll use pandas get_dummies to create columns with each categorical feature option,
#in this case only the Foundation

data['Foundation'] = le.inverse_transform(data['Foundation'])
data

# %%
data = pd.get_dummies(data)
data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split



#Here we are splitting our data with 2 pieces: train and test. Test will have 33% of data; train will have all the rest
test, train = train_test_split(data,test_size=0.3, random_state=42)

testSalePrice = test['SalePrice']
trainSalePrice = train['SalePrice']

train = train.drop(['SalePrice'], axis=1)
test = test.drop(['SalePrice'], axis=1)

model = LinearRegression()

model.fit(train, trainSalePrice) 

predict = model.predict(test)

predict

# %% [markdown]
# Excellent, we have our prediction Sale Prices! But how can we measure how accuracy is this prediction? Using the mean_squared_error from sklearn

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

MSE = mean_squared_error(predict,testSalePrice)
RMSE = np.sqrt(MSE) 
print('MSE:',MSE,'RMSE:',RMSE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e586607b7289> in <module>
#       2 import numpy as np
#       3
# ----> 4 MSE = mean_squared_error(predict,testSalePrice)
#       5 RMSE = np.sqrt(MSE)
#       6 print('MSE:',MSE,'RMSE:',RMSE)
#
# NameError: name 'predict' is not defined

# %%
import numpy as np 
import sklearn.metrics as metrics
import matplotlib.pyplot as plt

y = np.array(   [-2, -1, -2, 1, -1, 1, 2, 1, 3, 4, 3, 5])
yhat = np.array([-1, -1, -1, 1, -1, 1, 1, 1, 3, 4, 3, 5])
x = list(range(len(y)))


plt.scatter(x, y, color="green", label="original")
plt.plot(x, yhat, color="blue", label="Previsto")
plt.legend()
plt.show() 

# calculate manually
d = y - yhat
mse_f = np.mean(d**2)
mae_f = np.mean(abs(d))
rmse_f = np.sqrt(mse_f)
r2_f = 1-(sum(d**2)/sum((y-np.mean(y))**2))

print("Resultados:")
print("MAE:",mae_f)
print("MSE:", mse_f)
print("RMSE:", rmse_f)
print("R-Squared:", r2_f)
# Out:
# Resultados:
# MAE: 0.25
# MSE: 0.25
# RMSE: 0.5
# R-Squared: 0.9497206703910615

# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\marcel.pinheiro\OneDrive\BIG DATA - SENAI\TCC\pesquisa-tcc.xlsx')
df.head(5)
# Out:
#           Carimbo de data/hora       Sexo Data de nascimento  \
# 0  2019/11/25 1:02:52 PM GMT-4  Masculino         2019-11-01
# 1  2019/11/25 1:11:18 PM GMT-4  Masculino         1994-01-26
# 2  2019/11/25 1:15:11 PM GMT-4  Masculino         1985-02-01
# 3  2019/11/25 1:15:19 PM GMT-4  Masculino         1984-02-09
# 4  2019/11/25 1:17:21 PM GMT-4  Masculino         1985-06-10
#
#   Você considera sua cor de pele como:     Escolaridade   Cidade Estado Civil  \
# 0                               Branca  Ensino superior      cba     Solteiro
# 1                               Branca  Ensino superior   Cuiabá       Casado
# 2                               Branca  Ensino superior   Cuiaba       Casado
# 3                               Branca  Ensino superior  Cuiabá        Casado
# 4                                Parda  Ensino superior   Cuiabá     Solteiro
#
#            Profissão                                         Refeição 1  \
# 0           Analista  150g Peito de Frango\\n100g Arroz branco\\n80g...
# 1        Estatístico                              1 un Pão \ 100ml Cafe
# 2             Medico                                                NaN
# 3  Servidor Público                               4 ovos\\n100g abacate
# 4      Administrador                                         1 salgado\
#
#                                           Refeição 2  \
# 0  150g Peito de Frango\n100g Arroz branco\n80g b...
# 1  100g arroz branco\n50g feijão\n150g carne verm...
# 2        300g Carne vermelha \300g Arroz \farofa100g
# 3                             3 ovos\n1 dose de whey
# 4        150g proteína\n250g legumes\n100g verduras
#
#                                           Refeição 3  \
# 0  150g Peito de Frango\n100g Arroz branco\n80g b...
# 1                            100ml Café\n10 bolachas
# 2                                                NaN
# 3  300g peito de frango\n150g batata doce ou mand...
# 4                                   100g carboidrato
#
#                                           Refeição 4  \
# 0  150g Peito de Frango\n100g Arroz branco\n80g b...
# 1  100g arroz branco\n50g feijão\n150g carne verm...
# 2                         400Grama Carne \400g massa
# 3                               3 ovos \n1 dose whey
# 4                    200g proteina\n200g carboidrato
#
#                                           Refeição 5  \
# 0  150g Peito de Frango\n100g Arroz branco\n80g b...
# 1                                                NaN
# 2                                                NaN
# 3                              400 g peito de frango
# 4                                                NaN
#
#                                           Refeição 6
# 0  150g Peito de Frango\n100g Arroz branco\n80g b...
# 1                                                NaN
# 2                                                NaN
# 3                                        1 dose whey
# 4                                                NaN

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

# teste = df.groupby('Profissão')

# # print(teste['Sexo'].value_counts())

# my_data = teste['Sexo'].value_counts()
# my_labels = df['Sexo']
# plt.bar(my_data, my_data )
# plt.title('My Title')
# plt.axis('equal')
# plt.show()


masc = df[df['Sexo'] == 'Masculino'].count()
fem = df[df['Sexo'] == 'Feminino'].count()

print(masc['Sexo'])

# xxx = df.groupby('Profissão')

# print(masc['Sexo'])

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2,masc, width, label='Masculino')
rects2 = ax.bar(x + width/2, fem, width, label='Feminino')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(df['Profissão'])
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Masculino', 'Feminino'
sizes = [masc['Sexo'], fem['Sexo']]
explode = (0, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import datetime as dt
import numpy as np
hoje = pd.to_datetime('14/06/2020')
df['Data de nascimento'] = pd.to_datetime(df['Data de nascimento'])

# df.info()
df2 = df.copy()

df2['year'] = pd.DatetimeIndex(df2['Data de nascimento']).year

df2['idade'] = 2020 - df2['year'] 
df2['FaixaEtaria'] = ''
df2['FaixaEtaria'] = np.where((df2['idade']<20), ' <20',df2['FaixaEtaria'])
df2['FaixaEtaria'] = np.where((df2['idade']>=20) & (df2['idade']<30), '20-29',df2['FaixaEtaria'])
df2['FaixaEtaria'] = np.where((df2['idade']>=30) & (df2['idade']<40), '30-39',df2['FaixaEtaria'])
df2['FaixaEtaria'] = np.where((df2['idade']>=40) & (df2['idade']<50), '40-49',df2['FaixaEtaria'])
df2['FaixaEtaria'] = np.where((df2['idade']>=50), '50+',df2['FaixaEtaria'])

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 17 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Carimbo de data/hora                  54 non-null     object
#  1   Sexo                                  54 non-null     object
#  2   Data de nascimento                    54 non-null     datetime64[ns]
#  3   Você considera sua cor de pele como:  54 non-null     object
#  4   Escolaridade                          54 non-null     object
#  5   Cidade                                54 non-null     object
#  6   Estado Civil                          54 non-null     object
#  7   Profissão                             54 non-null     object
#  8   Refeição 1                            51 non-null     object
#  9   Refeição 2                            50 non-null     object
#  10  Refeição 3                            49 non-null     object
#  11  Refeição 4                            34 non-null     object
#  12  Refeição 5                            20 non-null     object
#  13  Refeição 6                            19 non-null     object
#  14  year                                  54 non-null     int64
#  15  idade                                 54 non-null     int64
#  16  FaixaEtaria                           54 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(14)
# memory usage: 7.3+ KB

# %%
df3 = df2.groupby('FaixaEtaria')

import matplotlib.pyplot as plt
plt.plot(df3['FaixaEtaria'].count() +21)
plt.xlabel('Faixa etária')
plt.ylabel('Quantidade')
plt.show()
# df2
df3['FaixaEtaria'].count() + 21
# Out:
# FaixaEtaria
#  <20     28
# 20-29    32
# 30-39    38
# 40-49    31
# 50+      30
# Name: FaixaEtaria, dtype: int64

# %%
from collections import Counter
Refeicoes += df2['Refeição 1'] + df2['Refeição 2'] + df2['Refeição 3'] + df2['Refeição 4'] + df2['Refeição 5'] + df2['Refeição 6']
Refeicoes
Refeicoes.replace(to_replace= r'\\', value= '', regex=True)
Counter("".join(str(Refeicoes)).split()).most_common(1000)
# Out:
# [('NaN', 38),
#  ('de', 12),
#  ('1', 6),
#  ('3', 4),
#  ('2', 3),
#  ('pão', 3),
#  ('...', 3),
#  ('ou', 3),
#  ('colher', 3),
#  ('4', 2),
#  ('com', 2),
#  ('ovos', 2),
#  ('100g', 2),
#  ('g', 2),
#  ('0', 1),
#  ('150g', 1),
#  ('Peito', 1),
#  ('Frango\\\\n100g', 1),
#  ('Arroz', 1),
#  ('branco\\\\n80g...', 1),
#  ('ovos\\\\n100g', 1),
#  ('abacate3', 1),
#  ('ovos\\n1', 1),
#  ('dose', 1),
#  ('whey300...', 1),
#  ('5', 1),
#  ('fatia', 1),
#  ('integral\\', 1),
#  ('300ml', 1),
#  ('suco', 1),
#  ('verde\\', 1),
#  ('200ml', 1),
#  ('6', 1),
#  ('7', 1),
#  ('Café\\ovoBanana', 1),
#  ('Batata', 1),
#  ('doce,', 1),
#  ('carne,', 1),
#  ('legumesMaçã...', 1),
#  ('8', 1),
#  ('9', 1),
#  ('10', 1),
#  ('11', 1),
#  ('Leite', 1),
#  ('café\\bolacha', 1),
#  ('FrutaArroz,', 1),
#  ('feijão\\carn...', 1),
#  ('12', 1),
#  ('13', 1),
#  ('ovos1', 1),
#  ('banana', 1),
#  ('maçã200g', 1),
#  ('frango', 1),
#  ('carn...', 1),
#  ('14', 1),
#  ('claras\\1', 1),
#  ('ovo', 1),
#  ('inteiro\\', 1),
#  ('Suco', 1),
#  ('Limão', 1),
#  ('ovo...', 1),
#  ('15', 1),
#  ('16', 1),
#  ('17', 1),
#  ('18', 1),
#  ('19', 1),
#  ('caipira', 1),
#  ('\\nOu', 1),
#  ('250g', 1),
#  ('abacate\\nOu', 1),
#  ('350ml', 1),
#  ('suc...', 1),
#  ('20', 1),
#  ('Café\\ovos', 1),
#  ('Frutas', 1),
#  ('Verduras\\', 1),
#  ('carnesFrutasVerdura...', 1),
#  ('21', 1),
#  ('carne', 1),
#  ('arroz1', 1),
#  ('feijão...', 1),
#  ('22', 1),
#  ('23', 1),
#  ('24', 1),
#  ('25', 1),
#  ('Café', 1),
#  ('xícara\\1', 1),
#  ('salMuito', 1),
#  ('variável', 1),
#  ('as', 1),
#  ('ve...', 1),
#  ('26', 1),
#  ('27', 1),
#  ('pao', 1),
#  ('\\\\n200ml', 1),
#  ('cafe200g', 1),
#  ('carbo\\n200g', 1),
#  ('carne\\n...', 1),
#  ('28', 1),
#  ('29', 1),
#  ('30', 1),
#  ('31', 1),
#  ('32', 1),
#  ('33', 1),
#  ('34', 1),
#  ('35', 1),
#  ('36', 1),
#  ('37', 1),
#  ('pão\\café', 1),
#  ('leitepão\\café', 1),
#  ('almoço,', 1),
#  ('geralmente', 1),
#  ('38', 1),
#  ('39', 1),
#  ('40', 1),
#  ('41', 1),
#  ('42', 1),
#  ('43', 1),
#  ('44', 1),
#  ('45', 1),
#  ('46', 1),
#  ('47', 1),
#  ('48', 1),
#  ('49', 1),
#  ('100gr', 1),
#  ('pão\\1', 1),
#  ('chá', 1),
#  ('manteiga\\', 1),
#  ('xícar...', 1),
#  ('50', 1),
#  ('51', 1),
#  ('52', 1),
#  ('130', 1),
#  ('queijo', 1),
#  ('frescatino1', 1),
#  ('Fruta100', 1),
#  ('prot...', 1),
#  ('53', 1),
#  ('fatias', 1),
#  ('integral\\2', 1),
#  ('fritos1', 1),
#  ('fruta', 1),
#  ('dtype:', 1),
#  ('object', 1)]
