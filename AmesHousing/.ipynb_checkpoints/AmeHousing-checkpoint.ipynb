# %% [markdown]
# # Prevendo o preço de uma casa <br>Predicting the Price of a house

# %%
import pandas as pd
pd.options.display.max_rows = 100


df = pd.read_excel('AmesHousing.xls')
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0      NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1      NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2      NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3      NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4      NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# ...    ...       ...          ...  ...       ...     ...    ...          ...
# 2925   NaN       IR1          Lvl  ...         0     NaN  GdPrv          NaN
# 2926   NaN       IR1          Low  ...         0     NaN  MnPrv          NaN
# 2927   NaN       Reg          Lvl  ...         0     NaN  MnPrv         Shed
# 2928   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2929   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
#
#      Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0           0       5    2010       WD           Normal     215000
# 1           0       6    2010       WD           Normal     105000
# 2       12500       6    2010       WD           Normal     172000
# 3           0       4    2010       WD           Normal     244000
# 4           0       3    2010       WD           Normal     189900
# ...       ...     ...     ...       ...             ...        ...
# 2925        0       3    2006       WD           Normal     142500
# 2926        0       6    2006       WD           Normal     131000
# 2927      700       7    2006       WD           Normal     132000
# 2928        0       4    2006       WD           Normal     170000
# 2929        0      11    2006       WD           Normal     188000
#
# [2930 rows x 82 columns]

# %% [markdown]
# ## Análise exploratória de dados <br> Exploratory data analysis

# %% [markdown]
# #### Checando a situação dos dados do dataset <br> Checking the situation of the dataset data

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(df)
# profile = ProfileReport(df, title='Profiling Diabets',html={'style':{'full_width':True}})
# profile

# %% [markdown]
# #### Removendo features com mais de 80% de valores nulos ou zeros <br> Removing features with 80% or more null values or zeros

# %%
df = df.drop(['Pool Area' ,'Pool QC' ,'3Ssn Porch' ,'Low Qual Fin SF' ,'Misc Val' ,'Misc Feature' ,'Bsmt Half Bath' ,'Alley'
         ,'Screen Porch' ,'BsmtFin SF 2' ,'Enclosed Porch' ,'Fence'], axis=1)

# %% [markdown]
# #### Convertendo features texto para números para verificar a correlação, variancia, e etc <br> Converting the text features into numbers to verify correlaton, variation, etc TODO terminar de fazer labelencoder e inverse

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df = df.dropna()

# Categorical boolean mask
categorical_feature_mask = df.dtypes==object
# filter categorical columns using mask and turn it into a list
categorical_cols = df.columns[categorical_feature_mask].tolist()

for x in categorical_cols:
    df[x] = le.fit_transform(df[x])

df
# Out:
#       Order        PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# 0         1  526301100           20          3         141.0     31770
# 3         4  526353030           20          3          93.0     11160
# 4         5  527105010           60          3          74.0     13830
# 5         6  527105030           60          3          78.0      9978
# 8         9  527146030          120          3          39.0      5389
# ...     ...        ...          ...        ...           ...       ...
# 2915   2916  923227100           20          3          80.0     13384
# 2923   2924  923250060           20          3          80.0     17400
# 2924   2925  923251180           20          3         160.0     20000
# 2928   2929  924100070           20          3          77.0     10010
# 2929   2930  924151050           60          3          74.0      9627
#
#       Street  Lot Shape  Land Contour  Utilities  ...  Garage Qual  \
# 0          1          0             3          0  ...            3
# 3          1          3             3          0  ...            3
# 4          1          0             3          0  ...            3
# 5          1          0             3          0  ...            3
# 8          1          0             3          0  ...            3
# ...      ...        ...           ...        ...  ...          ...
# 2915       1          3             3          0  ...            3
# 2923       1          3             2          0  ...            3
# 2924       1          3             3          0  ...            3
# 2928       1          3             3          0  ...            3
# 2929       1          3             3          0  ...            3
#
#       Garage Cond  Paved Drive  Wood Deck SF  Open Porch SF  Mo Sold  Yr Sold  \
# 0               4            1           210             62        5     2010
# 3               4            2             0              0        4     2010
# 4               4            2           212             34        3     2010
# 5               4            2           360             36        6     2010
# 8               4            2           237            152        3     2010
# ...           ...          ...           ...            ...      ...      ...
# 2915            4            2           160              0        5     2006
# 2923            4            1           295             41        5     2006
# 2924            4            2           474              0        9     2006
# 2928            4            2           240             38        4     2006
# 2929            4            2           190             48       11     2006
#
#       Sale Type  Sale Condition  SalePrice
# 0             8               3     215000
# 3             8               3     244000
# 4             8               3     189900
# 5             8               3     195500
# 8             8               3     236500
# ...         ...             ...        ...
# 2915          8               3     140000
# 2923          8               3     160000
# 2924          8               0     131000
# 2928          8               3     170000
# 2929          8               3     188000
#
# [1156 rows x 70 columns]

# %% [markdown]
# #### Verificando a correlação entre as features e o target SalePrice e mantendo apenas com correlação > 0.1 <br> Checking the correlation between the features and the SalePrice target and keeping only the correlation > 0.1

# %%
corr = df.corrwith(df['SalePrice']).sort_values(ascending=False) 
print("Correlation \n",corr)
corr = corr[corr > 0.1]
print("\n Correlation +0.1 \n",corr)
# Out:
# Correlation
#  SalePrice         1.000000
# Overall Qual      0.792541
# Garage Cars       0.680339
# Gr Liv Area       0.674048
# Garage Area       0.664028
# Total Bsmt SF     0.622937
# 1st Flr SF        0.603259
# Year Remod/Add    0.537073
# Mas Vnr Area      0.535498
# Garage Yr Blt     0.534440
# Year Built        0.528616
# TotRms AbvGrd     0.509296
# Full Bath         0.499105
# Foundation        0.494524
# BsmtFin SF 1      0.427337
# Roof Style        0.354876
# Lot Frontage      0.312266
# Neighborhood      0.311877
# Bsmt Full Bath    0.307487
# Wood Deck SF      0.278542
# Open Porch SF     0.276846
# Lot Area          0.273388
# Sale Condition    0.225465
# Half Bath         0.210575
# 2nd Flr SF        0.205193
# Electrical        0.173019
# Paved Drive       0.164390
# Bsmt Unf SF       0.142154
# Central Air       0.142148
# Condition 2       0.130269
# Functional        0.126456
# Garage Cond       0.123660
# Fireplaces        0.119617
# Condition 1       0.099219
# House Style       0.098756
# Garage Qual       0.097995
# Exter Cond        0.097876
# Bedroom AbvGr     0.093122
# Roof Matl         0.090188
# BsmtFin Type 2    0.079614
# Bsmt Cond         0.078092
# Land Slope        0.064821
# Exterior 2nd      0.055096
# Exterior 1st      0.048549
# Mas Vnr Type      0.038924
# Mo Sold           0.033215
# Street            0.023488
# Yr Sold          -0.024294
# Heating          -0.031746
# BsmtFin Type 1   -0.043462
# Order            -0.045574
# Bldg Type        -0.046081
# Land Contour     -0.057520
# Kitchen AbvGr    -0.096297
# Lot Config       -0.099022
# Sale Type        -0.114661
# MS SubClass      -0.116074
# MS Zoning        -0.178989
# Fireplace Qu     -0.200104
# Overall Cond     -0.208925
# Garage Type      -0.252051
# PID              -0.258055
# Lot Shape        -0.271802
# Bsmt Exposure    -0.337532
# Heating QC       -0.433766
# Garage Finish    -0.470779
# Kitchen Qual     -0.684714
# Bsmt Qual        -0.693008
# Exter Qual       -0.699632
# Utilities              NaN
# dtype: float64
#
#  Correlation +0.1
#  SalePrice         1.000000
# Overall Qual      0.792541
# Garage Cars       0.680339
# Gr Liv Area       0.674048
# Garage Area       0.664028
# Total Bsmt SF     0.622937
# 1st Flr SF        0.603259
# Year Remod/Add    0.537073
# Mas Vnr Area      0.535498
# Garage Yr Blt     0.534440
# Year Built        0.528616
# TotRms AbvGrd     0.509296
# Full Bath         0.499105
# Foundation        0.494524
# BsmtFin SF 1      0.427337
# Roof Style        0.354876
# Lot Frontage      0.312266
# Neighborhood      0.311877
# Bsmt Full Bath    0.307487
# Wood Deck SF      0.278542
# Open Porch SF     0.276846
# Lot Area          0.273388
# Sale Condition    0.225465
# Half Bath         0.210575
# 2nd Flr SF        0.205193
# Electrical        0.173019
# Paved Drive       0.164390
# Bsmt Unf SF       0.142154
# Central Air       0.142148
# Condition 2       0.130269
# Functional        0.126456
# Garage Cond       0.123660
# Fireplaces        0.119617
# dtype: float64

# %%
columnsCorr =  pd.Series(name for name in corr.index)
df = df.filter(columnsCorr)
df
# Out:
#       SalePrice  Overall Qual  Garage Cars  Gr Liv Area  Garage Area  \
# 0        215000             6          2.0         1656        528.0
# 3        244000             7          2.0         2110        522.0
# 4        189900             5          2.0         1629        482.0
# 5        195500             6          2.0         1604        470.0
# 8        236500             8          2.0         1616        608.0
# ...         ...           ...          ...          ...          ...
# 2915     140000             5          1.0         1360        336.0
# 2923     160000             5          2.0         1126        484.0
# 2924     131000             5          2.0         1224        576.0
# 2928     170000             5          2.0         1389        418.0
# 2929     188000             7          3.0         2000        650.0
#
#       Total Bsmt SF  1st Flr SF  Year Remod/Add  Mas Vnr Area  Garage Yr Blt  \
# 0            1080.0        1656            1960         112.0         1960.0
# 3            2110.0        2110            1968           0.0         1968.0
# 4             928.0         928            1998           0.0         1997.0
# 5             926.0         926            1998          20.0         1998.0
# 8            1595.0        1616            1996           0.0         1995.0
# ...             ...         ...             ...           ...            ...
# 2915         1104.0        1360            1979         194.0         1969.0
# 2923         1126.0        1126            1977           0.0         1977.0
# 2924         1224.0        1224            1996           0.0         1960.0
# 2928         1389.0        1389            1975           0.0         1975.0
# 2929          996.0         996            1994          94.0         1993.0
#
#       ...  Half Bath  2nd Flr SF  Electrical  Paved Drive  Bsmt Unf SF  \
# 0     ...          0           0           2            1        441.0
# 3     ...          1           0           2            2       1045.0
# 4     ...          1         701           2            2        137.0
# 5     ...          1         678           2            2        324.0
# 8     ...          0           0           2            2        415.0
# ...   ...        ...         ...         ...          ...          ...
# 2915  ...          0           0           2            2        641.0
# 2923  ...          0           0           2            1        190.0
# 2924  ...          0           0           2            2          0.0
# 2928  ...          0           0           2            2        195.0
# 2929  ...          1        1004           2            2        238.0
#
#       Central Air  Condition 2  Functional  Garage Cond  Fireplaces
# 0               1            2           5            4           2
# 3               1            2           5            4           2
# 4               1            2           5            4           1
# 5               1            2           5            4           1
# 8               1            2           5            4           1
# ...           ...          ...         ...          ...         ...
# 2915            1            2           5            4           1
# 2923            1            2           5            4           1
# 2924            1            2           5            4           1
# 2928            1            2           5            4           1
# 2929            1            2           5            4           1
#
# [1156 rows x 33 columns]

# %% [markdown]
# ####  Verificando agora altas correlações entre as features e removendo as maiores que 0.8 <br> Checking the high correlations between features and removing the ones higher than 0.8

# %%
import numpy as np

# Create correlation matrix
corr_matrix = df.corr().abs()
print('Corr Matrix \n',corr_matrix)

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.8
to_drop = [column for column in upper.columns if any(upper[column] > 0.8)]

# Drop features 
df.drop(to_drop, axis=1, inplace=True)
df
# Out:
# Corr Matrix
#                  SalePrice  Overall Qual  Garage Cars  Gr Liv Area  \
# SalePrice        1.000000      0.792541     0.680339     0.674048
# Overall Qual     0.792541      1.000000     0.649215     0.527955
# Garage Cars      0.680339      0.649215     1.000000     0.502290
# Gr Liv Area      0.674048      0.527955     0.502290     1.000000
# Garage Area      0.664028      0.612520     0.840231     0.508491
# Total Bsmt SF    0.622937      0.562825     0.483523     0.457274
# 1st Flr SF       0.603259      0.513706     0.440134     0.521010
# Year Remod/Add   0.537073      0.594616     0.518648     0.308528
# Mas Vnr Area     0.535498      0.453027     0.413033     0.433884
# Garage Yr Blt    0.534440      0.607730     0.632124     0.253828
# Year Built       0.528616      0.607185     0.579485     0.208878
# TotRms AbvGrd    0.509296      0.383548     0.431184     0.797898
# Full Bath        0.499105      0.483742     0.496222     0.538113
# Foundation       0.494524      0.535700     0.511568     0.265532
# BsmtFin SF 1     0.427337      0.297918     0.246862     0.260807
# Roof Style       0.354876      0.311293     0.230136     0.215489
# Lot Frontage     0.312266      0.208798     0.286751     0.392018
# Neighborhood     0.311877      0.274322     0.277457     0.190969
# Bsmt Full Bath   0.307487      0.212383     0.146782     0.085939
# Wood Deck SF     0.278542      0.228026     0.248639     0.245926
# Open Porch SF    0.276846      0.276063     0.224903     0.342501
# Lot Area         0.273388      0.133386     0.174035     0.317837
# Sale Condition   0.225465      0.228253     0.192500     0.088319
# Half Bath        0.210575      0.154184     0.205069     0.419830
# 2nd Flr SF       0.205193      0.126886     0.162216     0.629556
# Electrical       0.173019      0.189499     0.207714     0.093551
# Paved Drive      0.164390      0.168692     0.121379     0.039744
# Bsmt Unf SF      0.142154      0.257922     0.234779     0.163729
# Central Air      0.142148      0.148141     0.140817     0.033663
# Condition 2      0.130269      0.168409     0.093398     0.124829
# Functional       0.126456      0.193717     0.100297     0.023478
# Garage Cond      0.123660      0.163484     0.096245     0.055784
# Fireplaces       0.119617      0.006640     0.047824     0.185264
#
#                 Garage Area  Total Bsmt SF  1st Flr SF  Year Remod/Add  \
# SalePrice          0.664028       0.622937    0.603259        0.537073
# Overall Qual       0.612520       0.562825    0.513706        0.594616
# Garage Cars        0.840231       0.483523    0.440134        0.518648
# Gr Liv Area        0.508491       0.457274    0.521010        0.308528
# Garage Area        1.000000       0.569486    0.529805        0.433157
# Total Bsmt SF      0.569486       1.000000    0.886689        0.343604
# 1st Flr SF         0.529805       0.886689    1.000000        0.295110
# Year Remod/Add     0.433157       0.343604    0.295110        1.000000
# Mas Vnr Area       0.448755       0.467718    0.469783        0.245853
# Garage Yr Blt      0.578068       0.394923    0.297613        0.709832
# Year Built         0.496446       0.422314    0.310859        0.687249
# TotRms AbvGrd      0.384409       0.249712    0.287803        0.248471
# Full Bath          0.396883       0.297151    0.292697        0.497624
# Foundation         0.445832       0.348304    0.265890        0.631329
# BsmtFin SF 1       0.348151       0.611129    0.554643        0.160372
# Roof Style         0.244761       0.375796    0.404674        0.124380
# Lot Frontage       0.360938       0.336862    0.390722        0.098541
# Neighborhood       0.314381       0.254166    0.260573        0.160164
# Bsmt Full Bath     0.220076       0.358585    0.314570        0.142804
# Wood Deck SF       0.239268       0.230508    0.229792        0.207937
# Open Porch SF      0.278802       0.295052    0.262347        0.231546
# Lot Area           0.226019       0.305993    0.320753        0.028990
# Sale Condition     0.157609       0.154143    0.098654        0.257784
# Half Bath          0.131964       0.155095    0.176388        0.136430
# 2nd Flr SF         0.085758       0.293469    0.328937        0.084471
# Electrical         0.168410       0.109171    0.106358        0.304251
# Paved Drive        0.101009       0.142616    0.136715        0.193950
# Bsmt Unf SF        0.187492       0.279320    0.223432        0.199657
# Central Air        0.135332       0.100014    0.080146        0.135627
# Condition 2        0.124828       0.147861    0.156618        0.095400
# Functional         0.082972       0.047876    0.054222        0.123095
# Garage Cond        0.069231       0.084006    0.053557        0.162148
# Fireplaces         0.004141       0.167241    0.216549        0.146230
#
#                 Mas Vnr Area  Garage Yr Blt  ...  Half Bath  2nd Flr SF  \
# SalePrice           0.535498       0.534440  ...   0.210575    0.205193
# Overall Qual        0.453027       0.607730  ...   0.154184    0.126886
# Garage Cars         0.413033       0.632124  ...   0.205069    0.162216
# Gr Liv Area         0.433884       0.253828  ...   0.419830    0.629556
# Garage Area         0.448755       0.578068  ...   0.131964    0.085758
# Total Bsmt SF       0.467718       0.394923  ...   0.155095    0.293469
# 1st Flr SF          0.469783       0.297613  ...   0.176388    0.328937
# Year Remod/Add      0.245853       0.709832  ...   0.136430    0.084471
# Mas Vnr Area        1.000000       0.301540  ...   0.111575    0.062672
# Garage Yr Blt       0.301540       1.000000  ...   0.150435    0.021040
# Year Built          0.335663       0.880494  ...   0.173832    0.032935
# TotRms AbvGrd       0.314558       0.192833  ...   0.407722    0.616006
# Full Bath           0.278391       0.518191  ...   0.048669    0.331853
# Foundation          0.284787       0.737208  ...   0.177307    0.066137
# BsmtFin SF 1        0.322721       0.206577  ...   0.051386    0.207704
# Roof Style          0.393882       0.135408  ...   0.048252    0.123649
# Lot Frontage        0.287231       0.073255  ...   0.061356    0.080536
# Neighborhood        0.235307       0.189980  ...   0.015642    0.024562
# Bsmt Full Bath      0.172132       0.163282  ...   0.053615    0.184579
# Wood Deck SF        0.167566       0.240685  ...   0.066103    0.067415
# Open Porch SF       0.128870       0.216515  ...   0.158653    0.144946
# Lot Area            0.147815       0.016479  ...   0.057195    0.060276
# Sale Condition      0.100317       0.283164  ...   0.007622    0.011329
# Half Bath           0.111575       0.150435  ...   1.000000    0.632562
# 2nd Flr SF          0.062672       0.021040  ...   0.632562    1.000000
# Electrical          0.114082       0.279338  ...   0.023634    0.005526
# Paved Drive         0.140916       0.287407  ...   0.065523    0.082149
# Bsmt Unf SF         0.118269       0.199746  ...   0.085231    0.025183
# Central Air         0.096346       0.221322  ...   0.078465    0.036853
# Condition 2         0.092182       0.088465  ...   0.002622    0.002917
# Functional          0.083664       0.174757  ...   0.044990    0.035919
# Garage Cond         0.088235       0.191467  ...   0.063798    0.012185
# Fireplaces          0.074733       0.187548  ...   0.047315    0.008494
#
#                 Electrical  Paved Drive  Bsmt Unf SF  Central Air  \
# SalePrice         0.173019     0.164390     0.142154     0.142148
# Overall Qual      0.189499     0.168692     0.257922     0.148141
# Garage Cars       0.207714     0.121379     0.234779     0.140817
# Gr Liv Area       0.093551     0.039744     0.163729     0.033663
# Garage Area       0.168410     0.101009     0.187492     0.135332
# Total Bsmt SF     0.109171     0.142616     0.279320     0.100014
# 1st Flr SF        0.106358     0.136715     0.223432     0.080146
# Year Remod/Add    0.304251     0.193950     0.199657     0.135627
# Mas Vnr Area      0.114082     0.140916     0.118269     0.096346
# Garage Yr Blt     0.279338     0.287407     0.199746     0.221322
# Year Built        0.299923     0.394251     0.169790     0.295590
# TotRms AbvGrd     0.079651     0.004267     0.194285     0.002438
# Full Bath         0.202868     0.151974     0.247623     0.123756
# Foundation        0.202387     0.210412     0.176036     0.178170
# BsmtFin SF 1      0.068305     0.128949     0.525258     0.063745
# Roof Style        0.061844     0.052708     0.038059     0.003761
# Lot Frontage      0.062856     0.059501     0.052931     0.065563
# Neighborhood      0.095555     0.043269     0.028127     0.024149
# Bsmt Full Bath    0.092609     0.072543     0.469572     0.082440
# Wood Deck SF      0.121197     0.075426     0.026860     0.079622
# Open Porch SF     0.092160     0.057014     0.096380     0.045050
# Lot Area          0.027470     0.003385     0.005206     0.035832
# Sale Condition    0.028724     0.043191     0.172149     0.036343
# Half Bath         0.023634     0.065523     0.085231     0.078465
# 2nd Flr SF        0.005526     0.082149     0.025183     0.036853
# Electrical        1.000000     0.154170     0.025739     0.221225
# Paved Drive       0.154170     1.000000     0.028065     0.374911
# Bsmt Unf SF       0.025739     0.028065     1.000000     0.027140
# Central Air       0.221225     0.374911     0.027140     1.000000
# Condition 2       0.010925     0.011021     0.015653     0.007882
# Functional        0.051970     0.017055     0.048703     0.027987
# Garage Cond       0.087762     0.244060     0.019716     0.310734
# Fireplaces        0.020007     0.034961     0.147542     0.027474
#
#                 Condition 2  Functional  Garage Cond  Fireplaces
# SalePrice          0.130269    0.126456     0.123660    0.119617
# Overall Qual       0.168409    0.193717     0.163484    0.006640
# Garage Cars        0.093398    0.100297     0.096245    0.047824
# Gr Liv Area        0.124829    0.023478     0.055784    0.185264
# Garage Area        0.124828    0.082972     0.069231    0.004141
# Total Bsmt SF      0.147861    0.047876     0.084006    0.167241
# 1st Flr SF         0.156618    0.054222     0.053557    0.216549
# Year Remod/Add     0.095400    0.123095     0.162148    0.146230
# Mas Vnr Area       0.092182    0.083664     0.088235    0.074733
# Garage Yr Blt      0.088465    0.174757     0.191467    0.187548
# Year Built         0.063905    0.196732     0.212138    0.155002
# TotRms AbvGrd      0.070041    0.038594     0.051283    0.092933
# Full Bath          0.084388    0.080270     0.124608    0.083620
# Foundation         0.069769    0.167843     0.146712    0.122256
# BsmtFin SF 1       0.120158    0.044547     0.045623    0.239984
# Roof Style         0.112167    0.009163     0.053725    0.044690
# Lot Frontage       0.060851    0.000964     0.053612    0.157697
# Neighborhood       0.066617    0.015966     0.009673    0.006971
# Bsmt Full Bath     0.050846    0.027875     0.037240    0.189429
# Wood Deck SF       0.045152    0.047184     0.088746    0.039346
# Open Porch SF      0.127174    0.051049     0.015945    0.007160
# Lot Area           0.039612    0.015881     0.039151    0.203609
# Sale Condition     0.049104    0.064725     0.024415    0.098818
# Half Bath          0.002622    0.044990     0.063798    0.047315
# 2nd Flr SF         0.002917    0.035919     0.012185    0.008494
# Electrical         0.010925    0.051970     0.087762    0.020007
# Paved Drive        0.011021    0.017055     0.244060    0.034961
# Bsmt Unf SF        0.015653    0.048703     0.019716    0.147542
# Central Air        0.007882    0.027987     0.310734    0.027474
# Condition 2        1.000000    0.012502     0.007039    0.005527
# Functional         0.012502    1.000000     0.000108    0.077160
# Garage Cond        0.007039    0.000108     1.000000    0.040177
# Fireplaces         0.005527    0.077160     0.040177    1.000000
#
# [33 rows x 33 columns]
#       SalePrice  Overall Qual  Garage Cars  Gr Liv Area  Total Bsmt SF  \
# 0        215000             6          2.0         1656         1080.0
# 3        244000             7          2.0         2110         2110.0
# 4        189900             5          2.0         1629          928.0
# 5        195500             6          2.0         1604          926.0
# 8        236500             8          2.0         1616         1595.0
# ...         ...           ...          ...          ...            ...
# 2915     140000             5          1.0         1360         1104.0
# 2923     160000             5          2.0         1126         1126.0
# 2924     131000             5          2.0         1224         1224.0
# 2928     170000             5          2.0         1389         1389.0
# 2929     188000             7          3.0         2000          996.0
#
#       Year Remod/Add  Mas Vnr Area  Garage Yr Blt  TotRms AbvGrd  Full Bath  \
# 0               1960         112.0         1960.0              7          1
# 3               1968           0.0         1968.0              8          2
# 4               1998           0.0         1997.0              6          2
# 5               1998          20.0         1998.0              7          2
# 8               1996           0.0         1995.0              5          2
# ...              ...           ...            ...            ...        ...
# 2915            1979         194.0         1969.0              8          1
# 2923            1977           0.0         1977.0              5          2
# 2924            1996           0.0         1960.0              7          1
# 2928            1975           0.0         1975.0              6          1
# 2929            1994          94.0         1993.0              9          2
#
#       ...  Half Bath  2nd Flr SF  Electrical  Paved Drive  Bsmt Unf SF  \
# 0     ...          0           0           2            1        441.0
# 3     ...          1           0           2            2       1045.0
# 4     ...          1         701           2            2        137.0
# 5     ...          1         678           2            2        324.0
# 8     ...          0           0           2            2        415.0
# ...   ...        ...         ...         ...          ...          ...
# 2915  ...          0           0           2            2        641.0
# 2923  ...          0           0           2            1        190.0
# 2924  ...          0           0           2            2          0.0
# 2928  ...          0           0           2            2        195.0
# 2929  ...          1        1004           2            2        238.0
#
#       Central Air  Condition 2  Functional  Garage Cond  Fireplaces
# 0               1            2           5            4           2
# 3               1            2           5            4           2
# 4               1            2           5            4           1
# 5               1            2           5            4           1
# 8               1            2           5            4           1
# ...           ...          ...         ...          ...         ...
# 2915            1            2           5            4           1
# 2923            1            2           5            4           1
# 2924            1            2           5            4           1
# 2928            1            2           5            4           1
# 2929            1            2           5            4           1
#
# [1156 rows x 30 columns]

# %%
profile = ProfileReport(df)
# ProfileReport.get_description
profile
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-77465188317e> in <module>
# ----> 1 profile = ProfileReport(df)
#       2 # ProfileReport.get_description
#       3 profile
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\__init__.py in __init__(self, df, **kwargs)
#      64         sample = kwargs.get('sample', df.head())
#      65
# ---> 66         description_set = describe(df, **kwargs)
#      67
#      68         self.html = to_html(sample,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\describe.py in describe(df, bins, check_correlation, correlation_threshold, correlation_overrides, check_recoded, pool_size, **kwargs)
#     390             if name not in names:
#     391                 names.append(name)
# --> 392     variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
#     393     variable_stats.columns.names = df.columns.names
#     394
#
# TypeError: concat() got an unexpected keyword argument 'join_axes'

# %% [markdown]
# #### Quando temos uma feature com baixa variação, ela não contribui muito para nosso modelo, já que varia pouco a informação. Por exemplo, uma feature onde todas as linhas possuem uma mesma informação, sua variação será zero. Para nosso modelo, estipulamos uma variação maior que 0.010 <br> When we have a feature with low variation, it does not contribute much to our model, since the information varies little. For example, a feature where all lines have the same information, their variation will be zero. For our model, we stipulate a variation greater than 0.010

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
dataScaler = scaler.fit(df)
dataScaler = scaler.transform(df)

dataScaler_df = pd.DataFrame(dataScaler, columns= df.columns)

print(dataScaler_df.var().sort_values(ascending = False))


df = df.loc[:,dataScaler_df.var() > 0.010]
df
# Out:
# Year Remod/Add    0.105528
# Bsmt Full Bath    0.069901
# Neighborhood      0.066409
# Half Bath         0.065355
# Garage Yr Blt     0.052899
# 2nd Flr SF        0.052016
# Garage Cars       0.048138
# Foundation        0.048082
# Bsmt Unf SF       0.038293
# Electrical        0.035713
# Sale Condition    0.034285
# Roof Style        0.032533
# Full Bath         0.030790
# Overall Qual      0.028883
# Paved Drive       0.028425
# Wood Deck SF      0.023531
# Central Air       0.021177
# Mas Vnr Area      0.019255
# Functional        0.017454
# TotRms AbvGrd     0.016808
# Fireplaces        0.016595
# Open Porch SF     0.015859
# SalePrice         0.015795
# Gr Liv Area       0.011269
# BsmtFin SF 1      0.009032
# Garage Cond       0.008933
# Lot Frontage      0.007582
# Total Bsmt SF     0.006132
# Lot Area          0.001485
# Condition 2       0.001349
# dtype: float64
#       SalePrice  Overall Qual  Garage Cars  Gr Liv Area  Year Remod/Add  \
# 0        215000             6          2.0         1656            1960
# 3        244000             7          2.0         2110            1968
# 4        189900             5          2.0         1629            1998
# 5        195500             6          2.0         1604            1998
# 8        236500             8          2.0         1616            1996
# ...         ...           ...          ...          ...             ...
# 2915     140000             5          1.0         1360            1979
# 2923     160000             5          2.0         1126            1977
# 2924     131000             5          2.0         1224            1996
# 2928     170000             5          2.0         1389            1975
# 2929     188000             7          3.0         2000            1994
#
#       Mas Vnr Area  Garage Yr Blt  TotRms AbvGrd  Full Bath  Foundation  ...  \
# 0            112.0         1960.0              7          1           1  ...
# 3              0.0         1968.0              8          2           1  ...
# 4              0.0         1997.0              6          2           2  ...
# 5             20.0         1998.0              7          2           2  ...
# 8              0.0         1995.0              5          2           2  ...
# ...            ...            ...            ...        ...         ...  ...
# 2915         194.0         1969.0              8          1           2  ...
# 2923           0.0         1977.0              5          2           1  ...
# 2924           0.0         1960.0              7          1           1  ...
# 2928           0.0         1975.0              6          1           1  ...
# 2929          94.0         1993.0              9          2           2  ...
#
#       Open Porch SF  Sale Condition  Half Bath  2nd Flr SF  Electrical  \
# 0                62               3          0           0           2
# 3                 0               3          1           0           2
# 4                34               3          1         701           2
# 5                36               3          1         678           2
# 8               152               3          0           0           2
# ...             ...             ...        ...         ...         ...
# 2915              0               3          0           0           2
# 2923             41               3          0           0           2
# 2924              0               0          0           0           2
# 2928             38               3          0           0           2
# 2929             48               3          1        1004           2
#
#       Paved Drive  Bsmt Unf SF  Central Air  Functional  Fireplaces
# 0               1        441.0            1           5           2
# 3               2       1045.0            1           5           2
# 4               2        137.0            1           5           1
# 5               2        324.0            1           5           1
# 8               2        415.0            1           5           1
# ...           ...          ...          ...         ...         ...
# 2915            2        641.0            1           5           1
# 2923            1        190.0            1           5           1
# 2924            2          0.0            1           5           1
# 2928            2        195.0            1           5           1
# 2929            2        238.0            1           5           1
#
# [1156 rows x 24 columns]

# %% [markdown]
# #### Convertemos nossas colunas de categoria para o formato original
