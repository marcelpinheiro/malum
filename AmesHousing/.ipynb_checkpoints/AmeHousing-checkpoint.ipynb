# %% [markdown]
# # Prevendo o preço de uma casa <br>Predicting the Price of a house

# %%
pd.options.display.max_rows = 100
import pandas as pd

df = pd.read_excel('AmesHousing.xls')
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0      NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1      NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2      NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3      NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4      NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# ...    ...       ...          ...  ...       ...     ...    ...          ...
# 2925   NaN       IR1          Lvl  ...         0     NaN  GdPrv          NaN
# 2926   NaN       IR1          Low  ...         0     NaN  MnPrv          NaN
# 2927   NaN       Reg          Lvl  ...         0     NaN  MnPrv         Shed
# 2928   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2929   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
#
#      Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0           0       5    2010       WD           Normal     215000
# 1           0       6    2010       WD           Normal     105000
# 2       12500       6    2010       WD           Normal     172000
# 3           0       4    2010       WD           Normal     244000
# 4           0       3    2010       WD           Normal     189900
# ...       ...     ...     ...       ...             ...        ...
# 2925        0       3    2006       WD           Normal     142500
# 2926        0       6    2006       WD           Normal     131000
# 2927      700       7    2006       WD           Normal     132000
# 2928        0       4    2006       WD           Normal     170000
# 2929        0      11    2006       WD           Normal     188000
#
# [2930 rows x 82 columns]

# %% [markdown]
# ## Análise exploratória de dados <br> Exploratory data analysis

# %% [markdown]
# #### Checando a situação dos dados do dataset <br> Checking the situation of the dataset data

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(df)
# profile = ProfileReport(df, title='Profiling Diabets',html={'style':{'full_width':True}})
# profile
# Out:
# C:\Users\marcel.pinheiro\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)

# %% [markdown]
# #### Removendo features com mais de 80% de valores nulos ou zeros <br> Removing features with 80% or more null values or zeros

# %%
df = df.drop(['Pool Area' ,'Pool QC' ,'3Ssn Porch' ,'Low Qual Fin SF' ,'Misc Val' ,'Misc Feature' ,'Bsmt Half Bath' ,'Alley'
         ,'Screen Porch' ,'BsmtFin SF 2' ,'Enclosed Porch' ,'Fence'], axis=1)

# %% [markdown]
# #### Convertendo features texto para números para verificar a correlação, variancia, e etc <br> Converting the text features into numbers to verify correlaton, variation, etc TODO terminar de fazer labelencoder e inverse

# %%
# Categorical boolean mask
categorical_feature_mask = df.dtypes==object
# filter categorical columns using mask and turn it into a list
categorical_cols = df.columns[categorical_feature_mask].tolist()

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# apply le on categorical feature columns
df[categorical_cols] = df[categorical_cols].apply(lambda col: le.fit_transform(col))

df[categorical_cols].head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     104         try:
# --> 105             res = _encode_python(values, uniques, encode)
#     106         except TypeError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py in _encode_python(values, uniques, encode)
#      58     if uniques is None:
# ---> 59         uniques = sorted(set(values))
#      60         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-65df4c28cfba> in <module>
#       8
#       9 # apply le on categorical feature columns
# ---> 10 df[categorical_cols] = df[categorical_cols].apply(lambda col: le.fit_transform(col))
#      11
#      12 df[categorical_cols].head(10)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-138-65df4c28cfba> in <lambda>(col)
#       8
#       9 # apply le on categorical feature columns
# ---> 10 df[categorical_cols] = df[categorical_cols].apply(lambda col: le.fit_transform(col))
#      11
#      12 df[categorical_cols].head(10)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     234         """
#     235         y = column_or_1d(y, warn=True)
# --> 236         self.classes_, y = _encode(y, encode=True)
#     237         return y
#     238
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     105             res = _encode_python(values, uniques, encode)
#     106         except TypeError:
# --> 107             raise TypeError("argument must be a string or number")
#     108         return res
#     109     else:
#
# TypeError: ('argument must be a string or number', 'occurred at index Mas Vnr Type')

# %% [markdown]
# #### Verificando a correlação entre as features e o target SalePrice e mantendo apenas com correlação > 0.1 <br> Checking the correlation between the features and the SalePrice target and keeping only the correlation > 0.1

# %%
corr = df.corrwith(df['SalePrice']).sort_values(ascending=False) 
print("Correlation \n",corr)
corr = corr[corr > 0.1]
print("\n Correlation +0.1 \n",corr)
# Out:
# Correlation
#  SalePrice            1.000000
# Overall Qual         0.799262
# Gr Liv Area          0.706780
# Garage Cars          0.647877
# Garage Area          0.640401
#                        ...
# Mas Vnr Type_None   -0.403962
# Garage Finish_Unf   -0.421876
# Bsmt Qual_TA        -0.452487
# Kitchen Qual_TA     -0.526721
# Exter Qual_TA       -0.590897
# Length: 284, dtype: float64
#
#  Correlation +0.1
#  SalePrice                 1.000000
# Overall Qual              0.799262
# Gr Liv Area               0.706780
# Garage Cars               0.647877
# Garage Area               0.640401
# Total Bsmt SF             0.632280
# 1st Flr SF                0.621676
# Bsmt Qual_Ex              0.593567
# Year Built                0.558426
# Full Bath                 0.545604
# Kitchen Qual_Ex           0.537561
# Year Remod/Add            0.532974
# Garage Yr Blt             0.526965
# Foundation_PConc          0.520966
# Mas Vnr Area              0.508285
# TotRms AbvGrd             0.495474
# Exter Qual_Ex             0.480477
# Fireplaces                0.474558
# BsmtFin Type 1_GLQ        0.455326
# Heating QC_Ex             0.454553
# Exter Qual_Gd             0.446489
# Neighborhood_NridgHt      0.433299
# BsmtFin SF 1              0.432914
# Garage Finish_Fin         0.424902
# Fireplace Qu_Gd           0.371630
# Lot Frontage              0.357318
# Bsmt Exposure_Gd          0.355665
# Sale Type_New             0.354292
# Sale Condition_Partial    0.350122
# Garage Type_Attchd        0.345635
# Exterior 1st_VinylSd      0.334416
# Exterior 2nd_VinylSd      0.331146
# Wood Deck SF              0.327143
# Open Porch SF             0.312951
# Kitchen Qual_Gd           0.304463
# Mas Vnr Type_Stone        0.304290
# Neighborhood_NoRidge      0.295005
# Half Bath                 0.285056
# Roof Style_Hip            0.276522
# Garage Cond_TA            0.276430
# Bsmt Full Bath            0.276050
# Paved Drive_Y             0.273314
# 2nd Flr SF                0.269373
# Lot Shape_IR1             0.267209
# Lot Area                  0.266549
# Central Air_Y             0.264506
# Garage Qual_TA            0.255691
# Fireplace Qu_Ex           0.250029
# Mas Vnr Type_BrkFace      0.246106
# MS Zoning_RL              0.244217
# Electrical_SBrkr          0.239633
# Neighborhood_StoneBr      0.239009
# Garage Type_BuiltIn       0.223439
# Bsmt Qual_Gd              0.221187
# House Style_2Story        0.213645
# Land Contour_HLS          0.189201
# Bsmt Unf SF               0.182855
# Garage Finish_RFn         0.169175
# Neighborhood_Somerst      0.157593
# Fireplace Qu_TA           0.150991
# Bedroom AbvGr             0.143913
# Lot Config_CulDSac        0.143293
# Exterior 1st_CemntBd      0.142094
# Exterior 2nd_CmentBd      0.139155
# Bsmt Exposure_Av          0.136067
# Neighborhood_Timber       0.130763
# Condition 2_PosA          0.122533
# Functional_Typ            0.119343
# Roof Matl_WdShngl         0.118591
# Exter Cond_TA             0.117391
# BsmtFin Type 2_Unf        0.113448
# Bsmt Cond_TA              0.110261
# Bldg Type_1Fam            0.110180
# MS Zoning_FV              0.106706
# Condition 1_Norm          0.101302
# dtype: float64

# %%
pd.Series(name for name in corr.index)
df = df.filter(columnsCorr)
df
# Out:
# 0          SalePrice
# 1       Overall Qual
# 2        Garage Cars
# 3        Gr Liv Area
# 4        Garage Area
# 5      Total Bsmt SF
# 6         1st Flr SF
# 7         Year Built
# 8     Year Remod/Add
# 9      Garage Yr Blt
# 10        Foundation
# 11         Full Bath
# 12      Mas Vnr Area
# 13     TotRms AbvGrd
# 14          Lot Area
# 15      BsmtFin SF 1
# 16     Open Porch SF
# 17      Lot Frontage
# 18        Roof Style
# 19      Neighborhood
# 20    Bsmt Full Bath
# 21        2nd Flr SF
# 22      Wood Deck SF
# 23    Sale Condition
# 24         Half Bath
# 25        Electrical
# 26       Paved Drive
# 27       Central Air
# 28       Garage Cond
# 29        Functional
# 30       Bsmt Unf SF
# 31       Garage Qual
# 32       House Style
# 33       Condition 1
# 34        Exter Cond
# 35       Condition 2
# dtype: object
#       SalePrice  Overall Qual  Garage Cars  Gr Liv Area  Garage Area  \
# 0           299             4            1          379          191
# 3           354             5            1          599          186
# 4           241             3            1          360          153
# 5           257             4            1          344          142
# 8           338             6            1          352          238
# ...         ...           ...          ...          ...          ...
# 2915         92             3            0          191           60
# 2923        149             3            1           83          155
# 2924         69             3            1          118          221
# 2928        183             3            1          209          101
# 2929        235             5            2          561          265
#
#       Total Bsmt SF  1st Flr SF  Year Built  Year Remod/Add  Garage Yr Blt  \
# 0               271         562          55              10             47
# 3               671         692          63              18             55
# 4               176         125          92              48             84
# 5               175         123          93              48             85
# 8               533         542          90              46             82
# ...             ...         ...         ...             ...            ...
# 2915            289         398          64              29             56
# 2923            300         255          72              27             64
# 2924            355         319          55              46             47
# 2928            437         416          69              25             62
# 2929            221         167          88              44             80
#
#       ...  Paved Drive  Central Air  Garage Cond  Functional  Bsmt Unf SF  \
# 0     ...            1            1            4           5          255
# 3     ...            2            1            4           5          553
# 4     ...            2            1            4           5           61
# 5     ...            2            1            4           5          184
# 8     ...            2            1            4           5          238
# ...   ...          ...          ...          ...         ...          ...
# 2915  ...            2            1            4           5          383
# 2923  ...            1            1            4           5           93
# 2924  ...            2            1            4           5            0
# 2928  ...            2            1            4           5           96
# 2929  ...            2            1            4           5          125
#
#       Garage Qual  House Style  Condition 1  Exter Cond  Condition 2
# 0               3            2            2           3            2
# 3               3            2            2           3            2
# 4               3            5            2           3            2
# 5               3            5            2           3            2
# 8               3            2            2           3            2
# ...           ...          ...          ...         ...          ...
# 2915            3            2            2           3            2
# 2923            3            2            2           3            2
# 2924            3            2            2           3            2
# 2928            3            2            2           3            2
# 2929            3            5            2           3            2
#
# [1156 rows x 36 columns]

# %% [markdown]
# ####  Verificando agora altas correlações entre as features e removendo as maiores que 0.8 <br> Checking the high correlations between features and removing the ones higher than 0.8

# %%
import numpy as np

# Create correlation matrix
corr_matrix = df.corr().abs()
print('Corr Matrix \n',corr_matrix)

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.8
to_drop = [column for column in upper.columns if any(upper[column] > 0.8)]

# Drop features 
df.drop(to_drop, axis=1, inplace=True)
df
# Out:
# Corr Matrix
#                  SalePrice  Overall Qual  Garage Cars  Gr Liv Area  \
# SalePrice        1.000000      0.820081     0.722871     0.721326
# Overall Qual     0.820081      1.000000     0.649215     0.536719
# Garage Cars      0.722871      0.649215     1.000000     0.536123
# Gr Liv Area      0.721326      0.536719     0.536123     1.000000
# Garage Area      0.710244      0.625219     0.850929     0.524072
# Total Bsmt SF    0.663148      0.569177     0.520032     0.348129
# 1st Flr SF       0.624095      0.506988     0.461879     0.423831
# Year Built       0.623688      0.624764     0.596622     0.260163
# Year Remod/Add   0.623152      0.594616     0.518648     0.339833
# Garage Yr Blt    0.610915      0.612516     0.635616     0.278564
# Foundation       0.572155      0.535700     0.511568     0.303595
# Full Bath        0.553863      0.483742     0.496222     0.552449
# Mas Vnr Area     0.525014      0.475236     0.443789     0.418735
# TotRms AbvGrd    0.502842      0.382861     0.431785     0.792801
# Lot Area         0.452558      0.252967     0.373874     0.469071
# BsmtFin SF 1     0.413326      0.277216     0.258017     0.159043
# Open Porch SF    0.362123      0.301837     0.253113     0.326328
# Lot Frontage     0.348636      0.216151     0.321079     0.376811
# Roof Style       0.316342      0.311293     0.230136     0.208762
# Neighborhood     0.316032      0.274322     0.277457     0.220234
# Bsmt Full Bath   0.303159      0.212383     0.146782     0.074306
# 2nd Flr SF       0.297160      0.195061     0.241792     0.673289
# Wood Deck SF     0.290165      0.229243     0.244659     0.219923
# Sale Condition   0.253062      0.228253     0.192500     0.097535
# Half Bath        0.219128      0.154184     0.205069     0.444717
# Electrical       0.208696      0.189499     0.207714     0.104620
# Paved Drive      0.187297      0.168692     0.121379     0.037320
# Central Air      0.166198      0.148141     0.140817     0.032693
# Garage Cond      0.143604      0.163484     0.096245     0.054874
# Functional       0.142325      0.193717     0.100297     0.029768
# Bsmt Unf SF      0.127991      0.220731     0.192638     0.156738
# Garage Qual      0.125926      0.131327     0.159963     0.023612
# House Style      0.123160      0.107827     0.139048     0.260881
# Condition 1      0.120474      0.087018     0.086981     0.066917
# Exter Cond       0.117260      0.145816     0.135791     0.005377
# Condition 2      0.112493      0.168409     0.093398     0.092455
#
#                 Garage Area  Total Bsmt SF  1st Flr SF  Year Built  \
# SalePrice          0.710244       0.663148    0.624095    0.623688
# Overall Qual       0.625219       0.569177    0.506988    0.624764
# Garage Cars        0.850929       0.520032    0.461879    0.596622
# Gr Liv Area        0.524072       0.348129    0.423831    0.260163
# Garage Area        1.000000       0.575598    0.528549    0.517007
# Total Bsmt SF      0.575598       1.000000    0.877703    0.470893
# 1st Flr SF         0.528549       0.877703    1.000000    0.331946
# Year Built         0.517007       0.470893    0.331946    1.000000
# Year Remod/Add     0.443104       0.373538    0.312510    0.704723
# Garage Yr Blt      0.586044       0.434025    0.313637    0.894120
# Foundation         0.455624       0.382707    0.278911    0.794322
# Full Bath          0.411491       0.319533    0.299060    0.506788
# Mas Vnr Area       0.479471       0.464296    0.460124    0.368367
# TotRms AbvGrd      0.387099       0.175511    0.225953    0.161172
# Lot Area           0.413292       0.356195    0.414108    0.119541
# BsmtFin SF 1       0.327120       0.522020    0.463164    0.258968
# Open Porch SF      0.307291       0.268424    0.220957    0.263195
# Lot Frontage       0.382921       0.283454    0.343889    0.103157
# Roof Style         0.240148       0.364630    0.397387    0.163948
# Neighborhood       0.334819       0.295753    0.297653    0.194194
# Bsmt Full Bath     0.223714       0.352791    0.306942    0.194737
# 2nd Flr SF         0.182458       0.247177    0.275840    0.063419
# Wood Deck SF       0.249480       0.229100    0.221331    0.223100
# Sale Condition     0.154353       0.154803    0.095571    0.267472
# Half Bath          0.128771       0.220802    0.243285    0.177412
# Electrical         0.171368       0.126211    0.119607    0.299991
# Paved Drive        0.109856       0.161989    0.148396    0.381973
# Central Air        0.130223       0.110001    0.085181    0.289117
# Garage Cond        0.063869       0.095470    0.067779    0.207759
# Functional         0.084236       0.046723    0.073526    0.202129
# Bsmt Unf SF        0.137495       0.251482    0.191299    0.131018
# Garage Qual        0.102384       0.155978    0.128993    0.322844
# House Style        0.078614       0.299283    0.297428    0.229520
# Condition 1        0.055877       0.067495    0.058389    0.197581
# Exter Cond         0.069720       0.114622    0.072090    0.283740
# Condition 2        0.115657       0.110738    0.112154    0.068395
#
#                 Year Remod/Add  Garage Yr Blt  ...  Paved Drive  Central Air  \
# SalePrice             0.623152       0.610915  ...     0.187297     0.166198
# Overall Qual          0.594616       0.612516  ...     0.168692     0.148141
# Garage Cars           0.518648       0.635616  ...     0.121379     0.140817
# Gr Liv Area           0.339833       0.278564  ...     0.037320     0.032693
# Garage Area           0.443104       0.586044  ...     0.109856     0.130223
# Total Bsmt SF         0.373538       0.434025  ...     0.161989     0.110001
# 1st Flr SF            0.312510       0.313637  ...     0.148396     0.085181
# Year Built            0.704723       0.894120  ...     0.381973     0.289117
# Year Remod/Add        1.000000       0.714757  ...     0.193950     0.135627
# Garage Yr Blt         0.714757       1.000000  ...     0.285712     0.217839
# Foundation            0.631329       0.739394  ...     0.210412     0.178170
# Full Bath             0.497624       0.522320  ...     0.151974     0.123756
# Mas Vnr Area          0.263848       0.329428  ...     0.157004     0.107140
# TotRms AbvGrd         0.248590       0.197063  ...     0.004057     0.002284
# Lot Area              0.144469       0.119581  ...     0.017855     0.068770
# BsmtFin SF 1          0.164880       0.216127  ...     0.133980     0.069637
# Open Porch SF         0.253075       0.257088  ...     0.061534     0.052936
# Lot Frontage          0.096636       0.083452  ...     0.066223     0.070492
# Roof Style            0.124380       0.136556  ...     0.052708     0.003761
# Neighborhood          0.160164       0.190812  ...     0.043269     0.024149
# Bsmt Full Bath        0.142804       0.162937  ...     0.072543     0.082440
# 2nd Flr SF            0.145213       0.094634  ...     0.044738     0.019337
# Wood Deck SF          0.208478       0.240803  ...     0.080434     0.078612
# Sale Condition        0.257784       0.283671  ...     0.043191     0.036343
# Half Bath             0.136430       0.150993  ...     0.065523     0.078465
# Electrical            0.304251       0.280857  ...     0.154170     0.221225
# Paved Drive           0.193950       0.285712  ...     1.000000     0.374911
# Central Air           0.135627       0.217839  ...     0.374911     1.000000
# Garage Cond           0.162148       0.189835  ...     0.244060     0.310734
# Functional            0.123095       0.176187  ...     0.017055     0.027987
# Bsmt Unf SF           0.159115       0.153676  ...     0.061700     0.017142
# Garage Qual           0.167999       0.295546  ...     0.189289     0.222578
# House Style           0.188336       0.190318  ...     0.083566     0.070713
# Condition 1           0.160850       0.168305  ...     0.073284     0.089768
# Exter Cond            0.119695       0.225700  ...     0.166275     0.094566
# Condition 2           0.095400       0.089101  ...     0.011021     0.007882
#
#                 Garage Cond  Functional  Bsmt Unf SF  Garage Qual  \
# SalePrice          0.143604    0.142325     0.127991     0.125926
# Overall Qual       0.163484    0.193717     0.220731     0.131327
# Garage Cars        0.096245    0.100297     0.192638     0.159963
# Gr Liv Area        0.054874    0.029768     0.156738     0.023612
# Garage Area        0.063869    0.084236     0.137495     0.102384
# Total Bsmt SF      0.095470    0.046723     0.251482     0.155978
# 1st Flr SF         0.067779    0.073526     0.191299     0.128993
# Year Built         0.207759    0.202129     0.131018     0.322844
# Year Remod/Add     0.162148    0.123095     0.159115     0.167999
# Garage Yr Blt      0.189835    0.176187     0.153676     0.295546
# Foundation         0.146712    0.167843     0.139480     0.263186
# Full Bath          0.124608    0.080270     0.230533     0.151571
# Mas Vnr Area       0.098328    0.089064     0.092807     0.134672
# TotRms AbvGrd      0.051395    0.039054     0.196929     0.007355
# Lot Area           0.073842    0.030023     0.050893     0.085591
# BsmtFin SF 1       0.049566    0.047609     0.569055     0.133199
# Open Porch SF      0.020807    0.066223     0.071935     0.065798
# Lot Frontage       0.057315    0.006166     0.059064     0.084131
# Roof Style         0.053725    0.009163     0.017912     0.087779
# Neighborhood       0.009673    0.015966     0.001622     0.057503
# Bsmt Full Bath     0.037240    0.027875     0.490699     0.110610
# 2nd Flr SF         0.015484    0.041774     0.026941     0.038999
# Wood Deck SF       0.088097    0.024756     0.055008     0.086771
# Sale Condition     0.024415    0.064725     0.152349     0.084913
# Half Bath          0.063798    0.044990     0.068240     0.019271
# Electrical         0.087762    0.051970     0.003184     0.079231
# Paved Drive        0.244060    0.017055     0.061700     0.189289
# Central Air        0.310734    0.027987     0.017142     0.222578
# Garage Cond        1.000000    0.000108     0.012025     0.387010
# Functional         0.000108    1.000000     0.045549     0.006930
# Bsmt Unf SF        0.012025    0.045549     1.000000     0.052894
# Garage Qual        0.387010    0.006930     0.052894     1.000000
# House Style        0.073087    0.091037     0.144725     0.106142
# Condition 1        0.064708    0.003760     0.030497     0.081230
# Exter Cond         0.105052    0.056893     0.089929     0.077307
# Condition 2        0.007039    0.012502     0.023910     0.026680
#
#                 House Style  Condition 1  Exter Cond  Condition 2
# SalePrice          0.123160     0.120474    0.117260     0.112493
# Overall Qual       0.107827     0.087018    0.145816     0.168409
# Garage Cars        0.139048     0.086981    0.135791     0.093398
# Gr Liv Area        0.260881     0.066917    0.005377     0.092455
# Garage Area        0.078614     0.055877    0.069720     0.115657
# Total Bsmt SF      0.299283     0.067495    0.114622     0.110738
# 1st Flr SF         0.297428     0.058389    0.072090     0.112154
# Year Built         0.229520     0.197581    0.283740     0.068395
# Year Remod/Add     0.188336     0.160850    0.119695     0.095400
# Garage Yr Blt      0.190318     0.168305    0.225700     0.089101
# Foundation         0.201925     0.160890    0.218565     0.069769
# Full Bath          0.198835     0.135702    0.047257     0.084388
# Mas Vnr Area       0.064201     0.028289    0.079873     0.089832
# TotRms AbvGrd      0.301082     0.075558    0.012644     0.070457
# Lot Area           0.064651     0.079570    0.020493     0.059324
# BsmtFin SF 1       0.107631     0.008385    0.040684     0.087806
# Open Porch SF      0.133140     0.076072    0.011352     0.089657
# Lot Frontage       0.105386     0.026437    0.004010     0.067832
# Roof Style         0.055298     0.068892    0.083320     0.112167
# Neighborhood       0.000585     0.002388    0.002460     0.066617
# Bsmt Full Bath     0.041434     0.001143    0.030814     0.050846
# 2nd Flr SF         0.546654     0.018259    0.053350     0.003701
# Wood Deck SF       0.100844     0.049598    0.001788     0.045108
# Sale Condition     0.001857     0.027412    0.080566     0.049104
# Half Bath          0.487822     0.055645    0.041691     0.002622
# Electrical         0.163417     0.125548    0.055141     0.010925
# Paved Drive        0.083566     0.073284    0.166275     0.011021
# Central Air        0.070713     0.089768    0.094566     0.007882
# Garage Cond        0.073087     0.064708    0.105052     0.007039
# Functional         0.091037     0.003760    0.056893     0.012502
# Bsmt Unf SF        0.144725     0.030497    0.089929     0.023910
# Garage Qual        0.106142     0.081230    0.077307     0.026680
# House Style        1.000000     0.071197    0.034280     0.004213
# Condition 1        0.071197     1.000000    0.095625     0.119009
# Exter Cond         0.034280     0.095625    1.000000     0.025349
# Condition 2        0.004213     0.119009    0.025349     1.000000
#
# [36 rows x 36 columns]
#       SalePrice  Garage Cars  Gr Liv Area  Total Bsmt SF  Year Built  \
# 0           299            1          379            271          55
# 3           354            1          599            671          63
# 4           241            1          360            176          92
# 5           257            1          344            175          93
# 8           338            1          352            533          90
# ...         ...          ...          ...            ...         ...
# 2915         92            0          191            289          64
# 2923        149            1           83            300          72
# 2924         69            1          118            355          55
# 2928        183            1          209            437          69
# 2929        235            2          561            221          88
#
#       Year Remod/Add  Foundation  Full Bath  Mas Vnr Area  TotRms AbvGrd  ...  \
# 0                 10           1          1            50              4  ...
# 3                 18           1          2             0              5  ...
# 4                 48           2          2             0              3  ...
# 5                 48           2          2             5              4  ...
# 8                 46           2          2             0              2  ...
# ...              ...         ...        ...           ...            ...  ...
# 2915              29           2          1           101              5  ...
# 2923              27           1          2             0              2  ...
# 2924              46           1          1             0              4  ...
# 2928              25           1          1             0              3  ...
# 2929              44           2          2            40              6  ...
#
#       Paved Drive  Central Air  Garage Cond  Functional  Bsmt Unf SF  \
# 0               1            1            4           5          255
# 3               2            1            4           5          553
# 4               2            1            4           5           61
# 5               2            1            4           5          184
# 8               2            1            4           5          238
# ...           ...          ...          ...         ...          ...
# 2915            2            1            4           5          383
# 2923            1            1            4           5           93
# 2924            2            1            4           5            0
# 2928            2            1            4           5           96
# 2929            2            1            4           5          125
#
#       Garage Qual  House Style  Condition 1  Exter Cond  Condition 2
# 0               3            2            2           3            2
# 3               3            2            2           3            2
# 4               3            5            2           3            2
# 5               3            5            2           3            2
# 8               3            2            2           3            2
# ...           ...          ...          ...         ...          ...
# 2915            3            2            2           3            2
# 2923            3            2            2           3            2
# 2924            3            2            2           3            2
# 2928            3            2            2           3            2
# 2929            3            5            2           3            2
#
# [1156 rows x 32 columns]

# %%
profile = ProfileReport(df)
ProfileReport.get_description
profile
# Out:
# C:\Users\marcel.pinheiro\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <function pandas_profiling.ProfileReport.get_description(self)>
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>33 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>1156 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>153.6 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>136.1 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>32 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Garage Cars"><code>Garage Cars</code></a> has 212 / 18.3% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Year Remod/Add"><code>Year Remod/Add</code></a> has 105 / 9.1% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Foundation"><code>Foundation</code></a> has 104 / 9.0% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Mas Vnr Area"><code>Mas Vnr Area</code></a> has 554 / 47.9% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_BsmtFin SF 1"><code>BsmtFin SF 1</code></a> has 308 / 26.6% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Open Porch SF"><code>Open Porch SF</code></a> has 362 / 31.3% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Neighborhood"><code>Neighborhood</code></a> has 17 / 1.5% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Bsmt Full Bath"><code>Bsmt Full Bath</code></a> has 603 / 52.2% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_2nd Flr SF"><code>2nd Flr SF</code></a> has 603 / 52.2% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_va

# %% [markdown]
# #### Quando temos uma feature com baixa variação, ela não contribui muito para nosso modelo, já que varia pouco a informação. Por exemplo, uma feature onde todas as linhas possuem uma mesma informação, sua variação será zero. Para nosso modelo, estipulamos uma variação maior que 0.010 <br> When we have a feature with low variation, it does not contribute much to our model, since the information varies little. For example, a feature where all lines have the same information, their variation will be zero. For our model, we stipulate a variation greater than 0.010

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
dataScaler = scaler.fit(df)
dataScaler = scaler.transform(df)

dataScaler_df = pd.DataFrame(dataScaler, columns= df.columns)

print(dataScaler_df.var().sort_values(ascending = False))


df = df.loc[:,dataScaler_df.var() > 0.010]
df
# Out:
# Year Remod/Add    0.105528
# BsmtFin SF 1      0.105306
# 2nd Flr SF        0.093693
# Mas Vnr Area      0.083973
# Bsmt Unf SF       0.082546
# Lot Area          0.079640
# Total Bsmt SF     0.077398
# Wood Deck SF      0.074350
# House Style       0.073549
# Gr Liv Area       0.072713
# Bsmt Full Bath    0.069901
# Year Built        0.069812
# SalePrice         0.069370
# Neighborhood      0.066409
# Half Bath         0.065355
# Open Porch SF     0.061075
# Garage Cars       0.048138
# Foundation        0.048082
# Lot Frontage      0.036873
# Electrical        0.035713
# Sale Condition    0.034285
# Roof Style        0.032533
# Full Bath         0.030790
# Paved Drive       0.028425
# TotRms AbvGrd     0.023960
# Central Air       0.021177
# Exter Cond        0.019819
# Functional        0.017454
# Garage Qual       0.015680
# Condition 1       0.010453
# Garage Cond       0.008933
# Condition 2       0.001349
# dtype: float64
#       SalePrice  Garage Cars  Gr Liv Area  Total Bsmt SF  Year Built  \
# 0           299            1          379            271          55
# 3           354            1          599            671          63
# 4           241            1          360            176          92
# 5           257            1          344            175          93
# 8           338            1          352            533          90
# ...         ...          ...          ...            ...         ...
# 2915         92            0          191            289          64
# 2923        149            1           83            300          72
# 2924         69            1          118            355          55
# 2928        183            1          209            437          69
# 2929        235            2          561            221          88
#
#       Year Remod/Add  Foundation  Full Bath  Mas Vnr Area  TotRms AbvGrd  ...  \
# 0                 10           1          1            50              4  ...
# 3                 18           1          2             0              5  ...
# 4                 48           2          2             0              3  ...
# 5                 48           2          2             5              4  ...
# 8                 46           2          2             0              2  ...
# ...              ...         ...        ...           ...            ...  ...
# 2915              29           2          1           101              5  ...
# 2923              27           1          2             0              2  ...
# 2924              46           1          1             0              4  ...
# 2928              25           1          1             0              3  ...
# 2929              44           2          2            40              6  ...
#
#       Half Bath  Electrical  Paved Drive  Central Air  Functional  \
# 0             0           2            1            1           5
# 3             1           2            2            1           5
# 4             1           2            2            1           5
# 5             1           2            2            1           5
# 8             0           2            2            1           5
# ...         ...         ...          ...          ...         ...
# 2915          0           2            2            1           5
# 2923          0           2            1            1           5
# 2924          0           2            2            1           5
# 2928          0           2            2            1           5
# 2929          1           2            2            1           5
#
#       Bsmt Unf SF  Garage Qual  House Style  Condition 1  Exter Cond
# 0             255            3            2            2           3
# 3             553            3            2            2           3
# 4              61            3            5            2           3
# 5             184            3            5            2           3
# 8             238            3            2            2           3
# ...           ...          ...          ...          ...         ...
# 2915          383            3            2            2           3
# 2923           93            3            2            2           3
# 2924            0            3            2            2           3
# 2928           96            3            2            2           3
# 2929          125            3            5            2           3
#
# [1156 rows x 30 columns]

# %%
df = df.apply(le.inverse_transform)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-b0724c9f6974> in <module>
# ----> 1 df = df.apply(le.inverse_transform)
#       2 df
#       3
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\label.py in inverse_transform(self, y)
#     279         if len(diff):
#     280             raise ValueError(
# --> 281                     "y contains previously unseen labels: %s" % str(diff))
#     282         y = np.asarray(y)
#     283         return self.classes_[y]
#
# ValueError: ('y contains previously unseen labels: [613 614 615 616 617 618 619 620 621 622 623 624 625 626 627 628 629 630\n 631 632 633 634 635 636 637 638 639 640 641 642 643 644 645 646 647 648\n 649 650 651 652 653 654 655 656 657 658 659 660 661 662 663 664 665 666\n 667 668 669 670 671 672 673 674 675 676 677 678 679 680 681 682 683 684\n 685 686 687 688 689 690 691 692 693 694 695 696 697 698 699 700 701 702\n 703 704 705 706 707 708 709 710 711 712 713 714 715 716 717 718 719 720\n 721 722 723 724 725 726 727 728 729 730 731 732 733 734 735 736 737 738\n 739 740 741 742 743 744 745 746 747 748 749 750 751 752 753 754 755 756\n 757 758 759 760 761 762 763 764 765 766 767 768 769 770 771 772 773 774\n 775 776 777 778 779 780 781 782 783 784 785 786 787]', 'occurred at index Gr Liv Area')
